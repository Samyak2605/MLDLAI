# %%
# !wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
# Out:
# --2025-12-31 21:09:14--  https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 2606:50c0:8003::154, 2606:50c0:8000::154, 2606:50c0:8002::154, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8003::154|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1115394 (1.1M) [text/plain]
# Saving to: ‘input.txt’
#
# input.txt           100%[===================>]   1.06M  4.39MB/s    in 0.2s
#
# 2025-12-31 21:09:14 (4.39 MB/s) - ‘input.txt’ saved [1115394/1115394]

# %%
with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

print(text[:100])
print("Total characters:", len(text))
# Out:
# First Citizen:
# Before we proceed any further, hear me speak.
#
# All:
# Speak, speak.
#
# First Citizen:
# You
# Total characters: 1115394

# %%
chars = sorted(list(set(text)))
vocab_size = len(chars)

print("Vocabulary size:", vocab_size)
print(''.join(chars))
# Out:
# Vocabulary size: 65
#
#  !$&',-.3:;?ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz

# %%
stoi = {ch: i for i, ch in enumerate(chars)}
itos = {i: ch for i, ch in enumerate(chars)}

def encode(s):
    return [stoi[c] for c in s]

def decode(l):
    return ''.join([itos[i] for i in l])

print(encode("hello"))
print(decode(encode("hello")))
# Out:
# [46, 43, 50, 50, 53]
# hello

# %%
import torch

data = torch.tensor(encode(text), dtype=torch.long)
print(data.shape)
# Out:
# torch.Size([1115394])

# %%
n = int(0.9 * len(data))
train_data = data[:n]
val_data = data[n:]
